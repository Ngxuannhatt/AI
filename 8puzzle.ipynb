# %%
# Đích đến để so sánh độ chính xác
GOAL = (1, 2, 3, 4, 5, 6, 7, 8, 0)

def print_board(state):
    for i in range(0, 9, 3):
        print(f"{state[i]} {state[i+1]} {state[i+2]}")
    print("-" * 10)

# 1. Hàm đếm xem có bao nhiêu số đang đứng đúng vị trí
def count_correct_positions(state):
    count = 0
    for i in range(9):
        # Không đếm số 0 (ô trống) vì ta chỉ cần các số từ 1-8 đúng vị trí
        if state[i] != 0 and state[i] == GOAL[i]:
            count += 1
    return count

# 2. Hàm tìm các trạng thái có thể đi tiếp
def get_neighbors(state):
    neighbors = []
    zero_index = state.index(0)
    row, col = divmod(zero_index, 3)
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)] # Lên, Xuống, Trái, Phải

    for dr, dc in directions:
        new_row, new_col = row + dr, col + dc
        if 0 <= new_row < 3 and 0 <= new_col < 3:
            new_zero_index = new_row * 3 + new_col
            new_state = list(state)
            new_state[zero_index], new_state[new_zero_index] = new_state[new_zero_index], new_state[zero_index]
            neighbors.append(tuple(new_state))
    return neighbors

# --- CHƯƠNG TRÌNH CHÍNH ---

# Nhập dữ liệu từ bàn phím
print("Nhap day so (9 so tu 0-8, cach nhau bang dau cach):")
# Ví dụ nhập: 1 2 3 0 4 6 7 5 8
input_data = input().split()
start_state = tuple(int(x) for x in input_data)

current_state = start_state
history = [current_state] # Lưu lịch sử các bước đã đi

print("\nBat dau qua trinh di chuyen :")
print_board(current_state)

while True:
   # 1. Lấy tất cả hàng xóm
    all_neighbors = get_neighbors(current_state)
    
    # 2. LỌC: Chỉ giữ lại những hàng xóm CHƯA TỪNG đi qua
    valid_neighbors = [n for n in all_neighbors if n not in history]
    
    # Nếu không còn nước đi nào mới (tất cả đều đã đi qua hoặc vào ngõ cụt)
    if not valid_neighbors:
        print("khong con nuoc di moi nao khac.")
        break
    
    best_neighbor = None
    max_correct = -1
    
    # Tìm trong các hàng xóm, cái nào có nhiều số đúng vị trí nhất
    for neighbor in valid_neighbors:
        correct_count = count_correct_positions(neighbor)
        if correct_count > max_correct:
            max_correct = correct_count
            best_neighbor = neighbor
    
    # Cập nhật trạng thái hiện tại
    current_state = best_neighbor
    history.append(current_state)
    
    print(f"Buoc tiep theo (Co {max_correct} so dung vi tri):")
    print_board(current_state)

    # Nếu đã đạt đến đích thì cũng dừng
    if current_state == GOAL:
        print("DA DAT DEN TRANG THAI DICH!")
        break
# Out:
# Nhap day so (9 so tu 0-8, cach nhau bang dau cach):
#
# Bat dau qua trinh di chuyen :
# 1 2 3
# 4 0 5
# 6 7 8
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 3
# 4 5 0
# 6 7 8
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 3
# 4 5 8
# 6 7 0
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 3
# 4 5 8
# 6 0 7
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 3
# 4 5 8
# 0 6 7
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 2 3
# 0 5 8
# 4 6 7
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 0 2 3
# 1 5 8
# 4 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 0 3
# 1 5 8
# 4 6 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 5 3
# 1 0 8
# 4 6 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 5 3
# 1 6 8
# 4 0 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 5 3
# 1 6 8
# 0 4 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 5 3
# 0 6 8
# 1 4 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 0 5 3
# 2 6 8
# 1 4 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 5 0 3
# 2 6 8
# 1 4 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 5 6 3
# 2 0 8
# 1 4 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 5 6 3
# 2 4 8
# 1 0 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 5 6 3
# 2 4 8
# 0 1 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 5 6 3
# 0 4 8
# 2 1 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 5 6 3
# 4 0 8
# 2 1 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 5 0 3
# 4 6 8
# 2 1 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 0 5 3
# 4 6 8
# 2 1 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 4 5 3
# 0 6 8
# 2 1 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 4 5 3
# 2 6 8
# 0 1 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 4 5 3
# 2 6 8
# 1 0 7
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 4 5 3
# 2 0 8
# 1 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 4 0 3
# 2 5 8
# 1 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 0 4 3
# 2 5 8
# 1 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 4 3
# 0 5 8
# 1 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 4 3
# 1 5 8
# 0 6 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 4 3
# 1 5 8
# 6 0 7
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 4 3
# 1 5 8
# 6 7 0
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 4 3
# 1 5 0
# 6 7 8
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 4 0
# 1 5 3
# 6 7 8
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 2 0 4
# 1 5 3
# 6 7 8
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 0 2 4
# 1 5 3
# 6 7 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 2 4
# 0 5 3
# 6 7 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 2 4
# 6 5 3
# 0 7 8
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 2 4
# 6 5 3
# 7 0 8
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 4
# 6 5 3
# 7 8 0
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 4
# 6 5 0
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 0
# 6 5 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 0 2
# 6 5 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 5 2
# 6 0 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 5 2
# 0 6 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 0 5 2
# 1 6 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 5 0 2
# 1 6 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 5 2 0
# 1 6 4
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 5 2 4
# 1 6 0
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 5 2 4
# 1 0 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 5 2 4
# 0 1 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 0 2 4
# 5 1 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 2 0 4
# 5 1 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 2 1 4
# 5 0 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 2 1 4
# 0 5 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 0 1 4
# 2 5 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 0 4
# 2 5 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 4 0
# 2 5 6
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 4 6
# 2 5 0
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 4 6
# 2 5 3
# 7 8 0
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 4 6
# 2 5 3
# 7 0 8
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 4 6
# 2 0 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 0 6
# 2 4 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 6 0
# 2 4 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 3
# 2 4 0
# 7 5 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 3
# 2 4 8
# 7 5 0
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 3
# 2 4 8
# 7 0 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 3
# 2 0 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 0 3
# 2 6 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 0 1 3
# 2 6 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 1 3
# 0 6 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 1 3
# 6 0 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 2 0 3
# 6 1 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 0 2 3
# 6 1 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 0 1 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 1 0 8
# 7 4 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 1 4 8
# 7 0 5
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 1 4 8
# 7 5 0
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 1 4 0
# 7 5 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 2 3
# 1 0 4
# 7 5 8
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 6 2 3
# 1 5 4
# 7 0 8
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 6 2 3
# 1 5 4
# 7 8 0
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 6 2 3
# 1 5 0
# 7 8 4
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 6 2 0
# 1 5 3
# 7 8 4
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 6 0 2
# 1 5 3
# 7 8 4
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 0 6 2
# 1 5 3
# 7 8 4
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 6 2
# 0 5 3
# 7 8 4
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 2
# 7 5 3
# 0 8 4
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 6 2
# 7 5 3
# 8 0 4
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 6 2
# 7 5 3
# 8 4 0
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 6 2
# 7 5 0
# 8 4 3
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 6 0
# 7 5 2
# 8 4 3
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 0 6
# 7 5 2
# 8 4 3
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 1 5 6
# 7 0 2
# 8 4 3
# ----------
# Buoc tiep theo (Co 1 so dung vi tri):
# 1 5 6
# 7 4 2
# 8 0 3
# ----------
# Buoc tiep theo (Co 2 so dung vi tri):
# 1 5 6
# 7 4 2
# 0 8 3
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 5 6
# 0 4 2
# 7 8 3
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 5 6
# 4 0 2
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 0 6
# 4 5 2
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 6 0
# 4 5 2
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 6 2
# 4 5 0
# 7 8 3
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 6 2
# 4 5 3
# 7 8 0
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 6 2
# 4 5 3
# 7 0 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 6 2
# 4 0 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 3 so dung vi tri):
# 1 0 2
# 4 6 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 4 so dung vi tri):
# 1 2 0
# 4 6 3
# 7 5 8
# ----------
# Buoc tiep theo (Co 5 so dung vi tri):
# 1 2 3
# 4 6 0
# 7 5 8
# ----------
# Buoc tiep theo (Co 6 so dung vi tri):
# 1 2 3
# 4 0 6
# 7 5 8
# ----------
# Buoc tiep theo (Co 7 so dung vi tri):
# 1 2 3
# 4 5 6
# 7 0 8
# ----------
# Buoc tiep theo (Co 8 so dung vi tri):
# 1 2 3
# 4 5 6
# 7 8 0
# ----------
# DA DAT DEN TRANG THAI DICH!
